# %%
import tensorflow as tf
import pickle

# %%
# Load the original model
model=pickle.load(open('emotion_detector.pkl','rb'))

# Convert to TensorFlow Lite with quantization
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

# Save the quantized model
with open('emotion_detector.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\Anirban\AppData\Local\Temp\tmpter38th2\assets
# INFO:tensorflow:Assets written to: C:\Users\Anirban\AppData\Local\Temp\tmpter38th2\assets
# Saved artifact at 'C:\Users\Anirban\AppData\Local\Temp\tmpter38th2'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 150, 150, 3), dtype=tf.float32, name='input_layer_8')
# Output Type:
#   TensorSpec(shape=(None, 7), dtype=tf.float32, name=None)
# Captures:
#   1799296920720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1799296921488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1799296921872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1799296920912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1799296922640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1799296922064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1799296920336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1799296923600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1799296923792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1799296924752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1799296924944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1799296924176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1799296922256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1799296925520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1799303594256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1799303595408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1799303594064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1799303596560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1799303594640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1799303597712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1799303597904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1799303598480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1799303598672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1799303599248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1799303599440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1799303600016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1799303602128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1799303602512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1799303603280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1799303604048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1799303603664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1799303605200: TensorSpec(shape=(), dtype=tf.resource, name=None)
